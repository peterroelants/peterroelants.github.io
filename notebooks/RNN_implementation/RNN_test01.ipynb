# %% [markdown]
# # One-neuron recurrent network
#
# ## Some info on simple models:
# * http://gradworks.umi.com/36/41/3641415.html
# * http://ieeexplore.ieee.org/stamp/stamp.jsp?tp=&arnumber=6547230
#
#
#
#
# Formula:
# $$y(k+1) = \sigma(w*y(k) + x)$$
#
# With $y(k)$ the output at time $k$, $w$ the feedback weight, $x$ the input signal, $sigma$ the non-linear transfer function.
#
# ## Systeemtheorie:
#
# * http://en.wikipedia.org/wiki/LTI_system_theory
#
# vanuit de cursus:
#
# $$x[k+1] = A x[k] + B u[k]$$
# $$y[k] = C x[k] + D u[k]$$
#
# Met $x[k]$ de toestand op moment $k$, $u[k]$ de input op moment $k$, en $y[k]$ de output op moment $k$.
#
# ## Kalman filters:
#
# * http://greg.czerniak.info/guides/kalman1/
# * http://prism2.mem.drexel.edu/~billgreen/slam/papers/kalmanIntro.pdf
# * http://www.cl.cam.ac.uk/~rmf25/papers/Understanding%20the%20Basis%20of%20the%20Kalman%20Filter.pdf
# * http://bilgin.esme.org/BitsBytes/KalmanFilterforDummies.aspx
# * http://en.wikipedia.org/wiki/Kalman_filter
#
#
#
# $$ x(k) = A x(k-1) + B u(k) $$
#
# With $x(k)$ the state at time $k$, $u(k)$ the input (control vector) at time $k$, $A$ the state transition matrix, $B$ the control matrix.
#
# ## Elman network
#
# * http://www.heatonresearch.com/wiki/Simple_Recurrent_Neural_Network
# * http://en.wikibooks.org/wiki/Artificial_Neural_Networks/Recurrent_Networks
# * https://web.stanford.edu/group/pdplab/pdphandbook/handbookch8.html
# * https://github.com/encog/encog-java-examples/blob/master/src/main/java/org/encog/examples/neural/recurrent/elman/ElmanXOR.java
# * https://code.google.com/p/encog-java/source/browse/trunk/encog-examples/src/org/encog/examples/neural/recurrent/elman/ElmanXOR.java?r=2423
# * http://jsalatas.ictpro.gr/implementation-of-elman-recurrent-neural-network-in-weka/
# * http://www.heatonresearch.com/node/2155
# * http://tracer.uc3m.es/tws/TimeSeriesWeb/recu.html#jordan
#
#
# ## Error surfaces of RNNs
#
# * http://ieeexplore.ieee.org/stamp/stamp.jsp?tp=&arnumber=6547230
# * http://machinelearning.wustl.edu/mlpapers/paper_files/NIPS2013_5166.pdf
#
# ### Temporal XOR
#
# * http://www.cse.unsw.edu.au/~billw/cs9444/TemporalProcessing-10-4up.pdf
# * http://www.cc.gatech.edu/~bhroleno/rnn_slides.pdf
#
#
#
# ## Backpropagation through time
#
# * http://www.ra.cs.uni-tuebingen.de/SNNS/UserManual/node163.html
# * http://deeplearning.cs.cmu.edu/pdfs/Werbos.backprop.pdf
# * http://en.wikipedia.org/wiki/Backpropagation_through_time
#
#
# ## More external info:
# * http://crl.ucsd.edu/~elman/Bulgaria/cs-counter.pdf
# * http://www.willamette.edu/~gorr/classes/cs449/rnn1.html
# * https://web.stanford.edu/group/pdplab/pdphandbook/handbookch8.html
# * http://www.nehalemlabs.net/prototype/blog/2013/10/10/implementing-a-recurrent-neural-network-in-python/
# * http://nikhilbuduma.com/2015/01/11/a-deep-dive-into-recurrent-neural-networks/
# * http://karpathy.github.io/2015/05/21/rnn-effectiveness/
# * http://www.cs.bham.ac.uk/~jxb/INC/l12.pdf
# * http://www.cs.toronto.edu/~graves/phd.pdf
